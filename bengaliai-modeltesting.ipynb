# %% [markdown]
# [Starter code used](https://www.kaggle.com/rsmits/keras-efficientnet-b3-training-inference)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

import tensorflow as tf
import keras
from keras.models import Model, Input
from keras.layers import Input, Dense, Lambda
from keras.optimizers import Adam
from keras.callbacks import Callback, ModelCheckpoint

import cv2 
from math import ceil
import gc
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tqdm.auto import tqdm

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# Using TensorFlow backend.
# /kaggle/input/weights-v1/Train1_model_13.h5
# /kaggle/input/weights-v1/Train1_model_12.h5
# /kaggle/input/weights-v1/Train1_model_14.h5
# /kaggle/input/weights-v1/Train1_model_11.h5
# /kaggle/input/bengaliai-cv19/test_image_data_0.parquet
# /kaggle/input/bengaliai-cv19/sample_submission.csv
# /kaggle/input/bengaliai-cv19/test_image_data_3.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_0.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_1.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_2.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_3.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_2.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_1.parquet
# /kaggle/input/bengaliai-cv19/class_map.csv
# /kaggle/input/bengaliai-cv19/test.csv
# /kaggle/input/bengaliai-cv19/train.csv

# %%
# Constants
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

HEIGHT = 137
WIDTH = 236
HEIGHT_NEW = 128
WIDTH_NEW = 128
CHANNELS = 3

BATCH_SIZE = 32 
TRAIN_DIR = '.'
TEST_SIZE = 1./8
EPOCHS = 40

RUN_NAME = 'Train1_'
PLOT_NAME1 = 'Train1_LossAndAccuracy.png'
PLOT_NAME2 = 'Train1_Recall.png'

# %% [markdown]
# # **Image Preprocessing**
#
# [ROI resize](https://www.kaggle.com/shawon10/bangla-graphemes-image-processing-deep-cnn)

# %%
def resize_roi(image, size=128):
    resized = {}
    resize_size=size
    
    _, thresh = cv2.threshold(image, 30, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    contours, _ = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]

    idx = 0 
    ls_xmin = []
    ls_ymin = []
    ls_xmax = []
    ls_ymax = []
    for cnt in contours:
        idx += 1
        x,y,w,h = cv2.boundingRect(cnt)
        ls_xmin.append(x)
        ls_ymin.append(y)
        ls_xmax.append(x + w)
        ls_ymax.append(y + h)
    xmin = min(ls_xmin)
    ymin = min(ls_ymin)
    xmax = max(ls_xmax)
    ymax = max(ls_ymax)

    roi = image[ymin:ymax,xmin:xmax]
    resized_roi = cv2.resize(roi, (resize_size, resize_size), interpolation=cv2.INTER_AREA)

    return resized_roi

# Image Prep
def resize_image(img, WIDTH_NEW, HEIGHT_NEW):
    # Invert
    img = 255 - img

    # Normalize
    img = (img * (255.0 / img.max())).astype(np.uint8)

    # Reshape
    img = img.reshape(HEIGHT, WIDTH)
    img = resize_roi(img)

    return img

# %% [markdown]
# # **Model Definition**

# %%
# Generalized mean pool - GeM
gm_exp = tf.Variable(3.0, dtype = tf.float32)
def generalized_mean_pool_2d(X):
    pool = (tf.reduce_mean(tf.abs(X**(gm_exp)), 
                        axis = [1, 2], 
                        keepdims = False) + 1.e-7)**(1./gm_exp)
    return pool

def create_model(input_shape):
    # Input Layer
    input_tensor = Input(shape = input_shape)
    
    # Create and Compile Model and show Summary
    x_model = keras.applications.nasnet.NASNetMobile(input_tensor=input_tensor, include_top=False, weights=None, pooling=None, classes=None)
    
    # UnFreeze all layers
    for layer in x_model.layers:
        layer.trainable = True
    
    # GeM
    lambda_layer = Lambda(generalized_mean_pool_2d)
    lambda_layer.trainable_weights.extend([gm_exp])
    x = lambda_layer(x_model.output)
    
    # multi output
    grapheme_root = Dense(168, activation = 'softmax', name = 'root')(x)
    vowel_diacritic = Dense(11, activation = 'softmax', name = 'vowel')(x)
    consonant_diacritic = Dense(7, activation = 'softmax', name = 'consonant')(x)

    # model
    model = Model(inputs = x_model.input, outputs = [grapheme_root, vowel_diacritic, consonant_diacritic])

    return model

# %%
model = create_model((HEIGHT_NEW, WIDTH_NEW, CHANNELS))
# Compile Model
model.load_weights('/kaggle/input/weights-v1/Train1_model_14.h5')
# Model Summary
print(model.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 128, 128, 3)  0
# __________________________________________________________________________________________________
# stem_conv1 (Conv2D)             (None, 63, 63, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# stem_bn1 (BatchNormalization)   (None, 63, 63, 32)   128         stem_conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 63, 63, 32)   0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_conv_1_stem_1 (Conv2D (None, 63, 63, 11)   352         activation_1[0][0]
# __________________________________________________________________________________________________
# reduction_bn_1_stem_1 (BatchNor (None, 63, 63, 11)   44          reduction_conv_1_stem_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 63, 63, 11)   0           reduction_bn_1_stem_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 63, 63, 32)   0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 67, 67, 11)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 69, 69, 32)   0           activation_4[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 32, 32, 11)   396         separable_conv_1_pad_reduction_le
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 32, 32, 11)   1920        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 32, 32, 11)   44          separable_conv_1_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 32, 32, 11)   44          separable_conv_1_reduction_right1
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 11)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 11)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 32, 32, 11)   396         activation_3[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 32, 32, 11)   660         activation_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 63, 63, 32)   0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 32, 32, 11)   44          separable_conv_2_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 32, 32, 11)   44          separable_conv_2_reduction_right1
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 69, 69, 32)   0           activation_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 63, 63, 32)   0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_add_1_stem_1 (Add)    (None, 32, 32, 11)   0           separable_conv_2_bn_reduction_lef
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 32, 32, 11)   1920        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 67, 67, 32)   0           activation_8[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 32, 32, 11)   0           reduction_add_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 32, 32, 11)   44          separable_conv_1_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 32, 32, 11)   1152        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 32, 32, 11)   220         activation_10[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 11)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 32, 32, 11)   44          separable_conv_1_reduction_right3
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 32, 32, 11)   44          separable_conv_1_reduction_left4_
# __________________________________________________________________________________________________
# reduction_pad_1_stem_1 (ZeroPad (None, 65, 65, 11)   0           reduction_bn_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 32, 32, 11)   660         activation_7[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 32, 32, 11)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 32, 32, 11)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# reduction_left2_stem_1 (MaxPool (None, 32, 32, 11)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 32, 32, 11)   44          separable_conv_2_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 32, 32, 11)   396         activation_9[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 32, 32, 11)   220         activation_11[0][0]
# __________________________________________________________________________________________________
# adjust_relu_1_stem_2 (Activatio (None, 63, 63, 32)   0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_add_2_stem_1 (Add)    (None, 32, 32, 11)   0           reduction_left2_stem_1[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# reduction_left3_stem_1 (Average (None, 32, 32, 11)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 32, 32, 11)   44          separable_conv_2_reduction_right3
# __________________________________________________________________________________________________
# reduction_left4_stem_1 (Average (None, 32, 32, 11)   0           reduction_add_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 32, 32, 11)   44          separable_conv_2_reduction_left4_
# __________________________________________________________________________________________________
# reduction_right5_stem_1 (MaxPoo (None, 32, 32, 11)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 64, 64, 32)   0           adjust_relu_1_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add3_stem_1 (Add)     (None, 32, 32, 11)   0           reduction_left3_stem_1[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 11)   0           reduction_add_2_stem_1[0][0]
#                                                                  reduction_left4_stem_1[0][0]
# __________________________________________________________________________________________________
# reduction_add4_stem_1 (Add)     (None, 32, 32, 11)   0           separable_conv_2_bn_reduction_lef
#                                                                  reduction_right5_stem_1[0][0]
# __________________________________________________________________________________________________
# cropping2d_1 (Cropping2D)       (None, 63, 63, 32)   0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# reduction_concat_stem_1 (Concat (None, 32, 32, 44)   0           reduction_add_2_stem_1[0][0]
#                                                                  reduction_add3_stem_1[0][0]
#                                                                  add_1[0][0]
#                                                                  reduction_add4_stem_1[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_1_stem_2 (Avera (None, 32, 32, 32)   0           adjust_relu_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_2_stem_2 (Avera (None, 32, 32, 32)   0           cropping2d_1[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 32, 32, 44)   0           reduction_concat_stem_1[0][0]
# __________________________________________________________________________________________________
# adjust_conv_1_stem_2 (Conv2D)   (None, 32, 32, 11)   352         adjust_avg_pool_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_conv_2_stem_2 (Conv2D)   (None, 32, 32, 11)   352         adjust_avg_pool_2_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_conv_1_stem_2 (Conv2D (None, 32, 32, 22)   968         activation_12[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 22)   0           adjust_conv_1_stem_2[0][0]
#                                                                  adjust_conv_2_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_bn_1_stem_2 (BatchNor (None, 32, 32, 22)   88          reduction_conv_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_bn_stem_2 (BatchNormaliz (None, 32, 32, 22)   88          concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 32, 32, 22)   0           reduction_bn_1_stem_2[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 32, 32, 22)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 35, 35, 22)   0           activation_13[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 37, 37, 22)   0           activation_15[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 16, 16, 22)   1034        separable_conv_1_pad_reduction_le
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 16, 16, 22)   1562        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 16, 16, 22)   88          separable_conv_1_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 16, 16, 22)   88          separable_conv_1_reduction_right1
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 16, 16, 22)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 16, 16, 22)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 16, 16, 22)   1034        activation_14[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 16, 16, 22)   1562        activation_16[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 32, 32, 22)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 16, 16, 22)   88          separable_conv_2_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 16, 16, 22)   88          separable_conv_2_reduction_right1
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 37, 37, 22)   0           activation_17[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 32, 32, 22)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add_1_stem_2 (Add)    (None, 16, 16, 22)   0           separable_conv_2_bn_reduction_lef
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 16, 16, 22)   1562        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 35, 35, 22)   0           activation_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 16, 16, 22)   0           reduction_add_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 16, 16, 22)   88          separable_conv_1_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 16, 16, 22)   1034        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 16, 16, 22)   682         activation_21[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 16, 16, 22)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 16, 16, 22)   88          separable_conv_1_reduction_right3
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 16, 16, 22)   88          separable_conv_1_reduction_left4_
# __________________________________________________________________________________________________
# reduction_pad_1_stem_2 (ZeroPad (None, 33, 33, 22)   0           reduction_bn_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 16, 16, 22)   1562        activation_18[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 16, 16, 22)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 16, 16, 22)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# reduction_left2_stem_2 (MaxPool (None, 16, 16, 22)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 16, 16, 22)   88          separable_conv_2_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 16, 16, 22)   1034        activation_20[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 16, 16, 22)   682         activation_22[0][0]
# __________________________________________________________________________________________________
# adjust_relu_1_0 (Activation)    (None, 32, 32, 44)   0           reduction_concat_stem_1[0][0]
# __________________________________________________________________________________________________
# reduction_add_2_stem_2 (Add)    (None, 16, 16, 22)   0           reduction_left2_stem_2[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# reduction_left3_stem_2 (Average (None, 16, 16, 22)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 16, 16, 22)   88          separable_conv_2_reduction_right3
# __________________________________________________________________________________________________
# reduction_left4_stem_2 (Average (None, 16, 16, 22)   0           reduction_add_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 16, 16, 22)   88          separable_conv_2_reduction_left4_
# __________________________________________________________________________________________________
# reduction_right5_stem_2 (MaxPoo (None, 16, 16, 22)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 33, 33, 44)   0           adjust_relu_1_0[0][0]
# __________________________________________________________________________________________________
# reduction_add3_stem_2 (Add)     (None, 16, 16, 22)   0           reduction_left3_stem_2[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 16, 16, 22)   0           reduction_add_2_stem_2[0][0]
#                                                                  reduction_left4_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add4_stem_2 (Add)     (None, 16, 16, 22)   0           separable_conv_2_bn_reduction_lef
#                                                                  reduction_right5_stem_2[0][0]
# __________________________________________________________________________________________________
# cropping2d_2 (Cropping2D)       (None, 32, 32, 44)   0           zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# reduction_concat_stem_2 (Concat (None, 16, 16, 88)   0           reduction_add_2_stem_2[0][0]
#                                                                  reduction_add3_stem_2[0][0]
#                                                                  add_2[0][0]
#                                                                  reduction_add4_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_1_0 (AveragePoo (None, 16, 16, 44)   0           adjust_relu_1_0[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_2_0 (AveragePoo (None, 16, 16, 44)   0           cropping2d_2[0][0]
# __________________________________________________________________________________________________
# adjust_conv_1_0 (Conv2D)        (None, 16, 16, 22)   968         adjust_avg_pool_1_0[0][0]
# __________________________________________________________________________________________________
# adjust_conv_2_0 (Conv2D)        (None, 16, 16, 22)   968         adjust_avg_pool_2_0[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 16, 16, 88)   0           reduction_concat_stem_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 16, 16, 44)   0           adjust_conv_1_0[0][0]
#                                                                  adjust_conv_2_0[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_0 (Conv2D)        (None, 16, 16, 44)   3872        activation_23[0][0]
# __________________________________________________________________________________________________
# adjust_bn_0 (BatchNormalization (None, 16, 16, 44)   176         concatenate_2[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_0 (BatchNormalizati (None, 16, 16, 44)   176         normal_conv_1_0[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 16, 16, 44)   0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 16, 16, 44)   0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 16, 16, 44)   0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 16, 16, 44)   0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 16, 16, 44)   0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_0 (None, 16, 16, 44)   3036        activation_24[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 16, 16, 44)   2332        activation_26[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_0 (None, 16, 16, 44)   3036        activation_28[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 16, 16, 44)   2332        activation_30[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_0 (None, 16, 16, 44)   2332        activation_32[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 16, 16, 44)   176         separable_conv_1_normal_left1_0[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 16, 16, 44)   176         separable_conv_1_normal_right1_0[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 16, 16, 44)   176         separable_conv_1_normal_left2_0[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 16, 16, 44)   176         separable_conv_1_normal_right2_0[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 16, 16, 44)   176         separable_conv_1_normal_left5_0[0
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 16, 16, 44)   0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 16, 16, 44)   0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 16, 16, 44)   0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 16, 16, 44)   0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 16, 16, 44)   0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_0 (None, 16, 16, 44)   3036        activation_25[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 16, 16, 44)   2332        activation_27[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_0 (None, 16, 16, 44)   3036        activation_29[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 16, 16, 44)   2332        activation_31[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_0 (None, 16, 16, 44)   2332        activation_33[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 16, 16, 44)   176         separable_conv_2_normal_left1_0[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 16, 16, 44)   176         separable_conv_2_normal_right1_0[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 16, 16, 44)   176         separable_conv_2_normal_left2_0[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 16, 16, 44)   176         separable_conv_2_normal_right2_0[
# __________________________________________________________________________________________________
# normal_left3_0 (AveragePooling2 (None, 16, 16, 44)   0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# normal_left4_0 (AveragePooling2 (None, 16, 16, 44)   0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# normal_right4_0 (AveragePooling (None, 16, 16, 44)   0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 16, 16, 44)   176         separable_conv_2_normal_left5_0[0
# __________________________________________________________________________________________________
# normal_add_1_0 (Add)            (None, 16, 16, 44)   0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_0 (Add)            (None, 16, 16, 44)   0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_0 (Add)            (None, 16, 16, 44)   0           normal_left3_0[0][0]
#                                                                  adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# normal_add_4_0 (Add)            (None, 16, 16, 44)   0           normal_left4_0[0][0]
#                                                                  normal_right4_0[0][0]
# __________________________________________________________________________________________________
# normal_add_5_0 (Add)            (None, 16, 16, 44)   0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# normal_concat_0 (Concatenate)   (None, 16, 16, 264)  0           adjust_bn_0[0][0]
#                                                                  normal_add_1_0[0][0]
#                                                                  normal_add_2_0[0][0]
#                                                                  normal_add_3_0[0][0]
#                                                                  normal_add_4_0[0][0]
#                                                                  normal_add_5_0[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 16, 16, 88)   0           reduction_concat_stem_2[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 16, 16, 264)  0           normal_concat_0[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_1 (Conv2 (None, 16, 16, 44)   3872        activation_34[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_1 (Conv2D)        (None, 16, 16, 44)   11616       activation_35[0][0]
# __________________________________________________________________________________________________
# adjust_bn_1 (BatchNormalization (None, 16, 16, 44)   176         adjust_conv_projection_1[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_1 (BatchNormalizati (None, 16, 16, 44)   176         normal_conv_1_1[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 16, 16, 44)   0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 16, 16, 44)   0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 16, 16, 44)   0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 16, 16, 44)   0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 16, 16, 44)   0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_1 (None, 16, 16, 44)   3036        activation_36[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 16, 16, 44)   2332        activation_38[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_1 (None, 16, 16, 44)   3036        activation_40[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 16, 16, 44)   2332        activation_42[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_1 (None, 16, 16, 44)   2332        activation_44[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 16, 16, 44)   176         separable_conv_1_normal_left1_1[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 16, 16, 44)   176         separable_conv_1_normal_right1_1[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 16, 16, 44)   176         separable_conv_1_normal_left2_1[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 16, 16, 44)   176         separable_conv_1_normal_right2_1[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 16, 16, 44)   176         separable_conv_1_normal_left5_1[0
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 16, 16, 44)   0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 16, 16, 44)   0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 16, 16, 44)   0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 16, 16, 44)   0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 16, 16, 44)   0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 16, 16, 44)   3036        activation_37[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 16, 16, 44)   2332        activation_39[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 16, 16, 44)   3036        activation_41[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 16, 16, 44)   2332        activation_43[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 16, 16, 44)   2332        activation_45[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 16, 16, 44)   176         separable_conv_2_normal_left1_1[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 16, 16, 44)   176         separable_conv_2_normal_right1_1[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 16, 16, 44)   176         separable_conv_2_normal_left2_1[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 16, 16, 44)   176         separable_conv_2_normal_right2_1[
# __________________________________________________________________________________________________
# normal_left3_1 (AveragePooling2 (None, 16, 16, 44)   0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# normal_left4_1 (AveragePooling2 (None, 16, 16, 44)   0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# normal_right4_1 (AveragePooling (None, 16, 16, 44)   0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 16, 16, 44)   176         separable_conv_2_normal_left5_1[0
# __________________________________________________________________________________________________
# normal_add_1_1 (Add)            (None, 16, 16, 44)   0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_1 (Add)            (None, 16, 16, 44)   0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_1 (Add)            (None, 16, 16, 44)   0           normal_left3_1[0][0]
#                                                                  adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# normal_add_4_1 (Add)            (None, 16, 16, 44)   0           normal_left4_1[0][0]
#                                                                  normal_right4_1[0][0]
# __________________________________________________________________________________________________
# normal_add_5_1 (Add)            (None, 16, 16, 44)   0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# normal_concat_1 (Concatenate)   (None, 16, 16, 264)  0           adjust_bn_1[0][0]
#                                                                  normal_add_1_1[0][0]
#                                                                  normal_add_2_1[0][0]
#                                                                  normal_add_3_1[0][0]
#                                                                  normal_add_4_1[0][0]
#                                                                  normal_add_5_1[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 16, 16, 264)  0           normal_concat_0[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 16, 16, 264)  0           normal_concat_1[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_2 (Conv2 (None, 16, 16, 44)   11616       activation_46[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_2 (Conv2D)        (None, 16, 16, 44)   11616       activation_47[0][0]
# __________________________________________________________________________________________________
# adjust_bn_2 (BatchNormalization (None, 16, 16, 44)   176         adjust_conv_projection_2[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_2 (BatchNormalizati (None, 16, 16, 44)   176         normal_conv_1_2[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 16, 16, 44)   0           normal_bn_1_2[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 16, 16, 44)   0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 16, 16, 44)   0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 16, 16, 44)   0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 16, 16, 44)   0           normal_bn_1_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_2 (None, 16, 16, 44)   3036        activation_48[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 16, 16, 44)   2332        activation_50[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_2 (None, 16, 16, 44)   3036        activation_52[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 16, 16, 44)   2332        activation_54[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_2 (None, 16, 16, 44)   2332        activation_56[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 16, 16, 44)   176         separable_conv_1_normal_left1_2[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 16, 16, 44)   176         separable_conv_1_normal_right1_2[
# ...
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 4, 4, 176)    35376       activation_167[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 4, 4, 176)    32560       activation_169[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 4, 4, 176)    35376       activation_171[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 4, 4, 176)    32560       activation_173[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 4, 4, 176)    32560       activation_175[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 4, 4, 176)    704         separable_conv_2_normal_left1_11[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 4, 4, 176)    704         separable_conv_2_normal_right1_11
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 4, 4, 176)    704         separable_conv_2_normal_left2_11[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 4, 4, 176)    704         separable_conv_2_normal_right2_11
# __________________________________________________________________________________________________
# normal_left3_11 (AveragePooling (None, 4, 4, 176)    0           normal_bn_1_11[0][0]
# __________________________________________________________________________________________________
# normal_left4_11 (AveragePooling (None, 4, 4, 176)    0           adjust_bn_11[0][0]
# __________________________________________________________________________________________________
# normal_right4_11 (AveragePoolin (None, 4, 4, 176)    0           adjust_bn_11[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 4, 4, 176)    704         separable_conv_2_normal_left5_11[
# __________________________________________________________________________________________________
# normal_add_1_11 (Add)           (None, 4, 4, 176)    0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_11 (Add)           (None, 4, 4, 176)    0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_11 (Add)           (None, 4, 4, 176)    0           normal_left3_11[0][0]
#                                                                  adjust_bn_11[0][0]
# __________________________________________________________________________________________________
# normal_add_4_11 (Add)           (None, 4, 4, 176)    0           normal_left4_11[0][0]
#                                                                  normal_right4_11[0][0]
# __________________________________________________________________________________________________
# normal_add_5_11 (Add)           (None, 4, 4, 176)    0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_11[0][0]
# __________________________________________________________________________________________________
# normal_concat_11 (Concatenate)  (None, 4, 4, 1056)   0           adjust_bn_11[0][0]
#                                                                  normal_add_1_11[0][0]
#                                                                  normal_add_2_11[0][0]
#                                                                  normal_add_3_11[0][0]
#                                                                  normal_add_4_11[0][0]
#                                                                  normal_add_5_11[0][0]
# __________________________________________________________________________________________________
# activation_176 (Activation)     (None, 4, 4, 1056)   0           normal_concat_10[0][0]
# __________________________________________________________________________________________________
# activation_177 (Activation)     (None, 4, 4, 1056)   0           normal_concat_11[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_12 (Conv (None, 4, 4, 176)    185856      activation_176[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_12 (Conv2D)       (None, 4, 4, 176)    185856      activation_177[0][0]
# __________________________________________________________________________________________________
# adjust_bn_12 (BatchNormalizatio (None, 4, 4, 176)    704         adjust_conv_projection_12[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_12 (BatchNormalizat (None, 4, 4, 176)    704         normal_conv_1_12[0][0]
# __________________________________________________________________________________________________
# activation_178 (Activation)     (None, 4, 4, 176)    0           normal_bn_1_12[0][0]
# __________________________________________________________________________________________________
# activation_180 (Activation)     (None, 4, 4, 176)    0           adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# activation_182 (Activation)     (None, 4, 4, 176)    0           adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# activation_184 (Activation)     (None, 4, 4, 176)    0           adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, 4, 4, 176)    0           normal_bn_1_12[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_1 (None, 4, 4, 176)    35376       activation_178[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 4, 4, 176)    32560       activation_180[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_1 (None, 4, 4, 176)    35376       activation_182[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 4, 4, 176)    32560       activation_184[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_1 (None, 4, 4, 176)    32560       activation_186[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 4, 4, 176)    704         separable_conv_1_normal_left1_12[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 4, 4, 176)    704         separable_conv_1_normal_right1_12
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 4, 4, 176)    704         separable_conv_1_normal_left2_12[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 4, 4, 176)    704         separable_conv_1_normal_right2_12
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 4, 4, 176)    704         separable_conv_1_normal_left5_12[
# __________________________________________________________________________________________________
# activation_179 (Activation)     (None, 4, 4, 176)    0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_181 (Activation)     (None, 4, 4, 176)    0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_183 (Activation)     (None, 4, 4, 176)    0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_185 (Activation)     (None, 4, 4, 176)    0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, 4, 4, 176)    0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 4, 4, 176)    35376       activation_179[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 4, 4, 176)    32560       activation_181[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 4, 4, 176)    35376       activation_183[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 4, 4, 176)    32560       activation_185[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 4, 4, 176)    32560       activation_187[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 4, 4, 176)    704         separable_conv_2_normal_left1_12[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 4, 4, 176)    704         separable_conv_2_normal_right1_12
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 4, 4, 176)    704         separable_conv_2_normal_left2_12[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 4, 4, 176)    704         separable_conv_2_normal_right2_12
# __________________________________________________________________________________________________
# normal_left3_12 (AveragePooling (None, 4, 4, 176)    0           normal_bn_1_12[0][0]
# __________________________________________________________________________________________________
# normal_left4_12 (AveragePooling (None, 4, 4, 176)    0           adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# normal_right4_12 (AveragePoolin (None, 4, 4, 176)    0           adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 4, 4, 176)    704         separable_conv_2_normal_left5_12[
# __________________________________________________________________________________________________
# normal_add_1_12 (Add)           (None, 4, 4, 176)    0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_12 (Add)           (None, 4, 4, 176)    0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_12 (Add)           (None, 4, 4, 176)    0           normal_left3_12[0][0]
#                                                                  adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# normal_add_4_12 (Add)           (None, 4, 4, 176)    0           normal_left4_12[0][0]
#                                                                  normal_right4_12[0][0]
# __________________________________________________________________________________________________
# normal_add_5_12 (Add)           (None, 4, 4, 176)    0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_12[0][0]
# __________________________________________________________________________________________________
# normal_concat_12 (Concatenate)  (None, 4, 4, 1056)   0           adjust_bn_12[0][0]
#                                                                  normal_add_1_12[0][0]
#                                                                  normal_add_2_12[0][0]
#                                                                  normal_add_3_12[0][0]
#                                                                  normal_add_4_12[0][0]
#                                                                  normal_add_5_12[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, 4, 4, 1056)   0           normal_concat_12[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 1056)         0           activation_188[0][0]
# __________________________________________________________________________________________________
# root (Dense)                    (None, 168)          177576      lambda_1[0][0]
# __________________________________________________________________________________________________
# vowel (Dense)                   (None, 11)           11627       lambda_1[0][0]
# __________________________________________________________________________________________________
# consonant (Dense)               (None, 7)            7399        lambda_1[0][0]
# ==================================================================================================
# Total params: 4,466,318
# Trainable params: 4,429,580
# Non-trainable params: 36,738
# __________________________________________________________________________________________________
# None

# %% [markdown]
# # **Testing**

# %%
class TestDataGenerator(keras.utils.Sequence):
    def __init__(self, X, batch_size = 16, img_size = (512, 512, 3), *args, **kwargs):
        self.X = X
        self.indices = np.arange(len(self.X))
        self.batch_size = batch_size
        self.img_size = img_size
                    
    def __len__(self):
        return int(ceil(len(self.X) / self.batch_size))

    def __getitem__(self, index):
        indices = self.indices[index*self.batch_size:(index+1)*self.batch_size]
        X = self.__data_generation(indices)
        return X
    
    def __data_generation(self, indices):
        X = np.empty((self.batch_size, *self.img_size))
        
        for i, index in enumerate(indices):
            image = self.X[index]
            image = np.stack((image,)*CHANNELS, axis=-1)
            image = image.reshape(-1, HEIGHT_NEW, WIDTH_NEW, CHANNELS)
            
            X[i,] = image
        
        return X

# %%
# Parquet file directory
parquetdir = '/kaggle/input/bengaliai-cv19'

# Create Submission File
tgt_cols = ['grapheme_root','vowel_diacritic','consonant_diacritic']

# Create Predictions
row_ids, targets = [], []

# Loop through Test Feather files (X)
for i in range(0, 4):
    # Test Files Placeholder
    test_files = []

    # Read Feather file
    df = pd.read_parquet(parquetdir+'/test_image_data_'+str(i)+'.parquet')
    
    # Get Image Id values
    image_ids = df['image_id'].values 
    # Drop Image_id column
    df = df.drop(['image_id'], axis = 1)

    # Loop over rows in Dataframe and generate images 
    X = []
    for image_id, index in zip(image_ids, range(df.shape[0])):
        test_files.append(image_id)
        X.append(resize_image(df.loc[df.index[index]].values, WIDTH_NEW, HEIGHT_NEW))

    # Data_Generator
    data_generator_test = TestDataGenerator(X, batch_size = BATCH_SIZE, img_size = (HEIGHT_NEW, WIDTH_NEW, CHANNELS))
    
    # Predict with model
    pred = model.predict_generator(data_generator_test, verbose = 1)

    # Loop over Preds    
    for i, image_id in zip(range(len(test_files)), test_files):        
        for subi, col in zip(range(len(pred)), tgt_cols):
            # Set Prediction
            row_ids.append(str(image_id)+'_'+col)
            targets.append(pred[subi])
    
    # Cleanup
    del df
    gc.collect()
# Out:
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 1s 722ms/step
# 1/1 [==============================] - 1s 740ms/step
# 1/1 [==============================] - 1s 718ms/step

# %% [markdown]
# # **Submission**

# %%
submit_df = pd.DataFrame({'row_id':row_ids,'target':targets}, columns = ['row_id','target'])
submit_df.to_csv('submission.csv', index = False)
print(submit_df.head(40))
# Out:
#                          row_id  \
# 0          Test_0_grapheme_root
# 1        Test_0_vowel_diacritic
# 2    Test_0_consonant_diacritic
# 3          Test_1_grapheme_root
# 4        Test_1_vowel_diacritic
# 5    Test_1_consonant_diacritic
# 6          Test_2_grapheme_root
# 7        Test_2_vowel_diacritic
# 8    Test_2_consonant_diacritic
# 9          Test_3_grapheme_root
# 10       Test_3_vowel_diacritic
# 11   Test_3_consonant_diacritic
# 12         Test_4_grapheme_root
# 13       Test_4_vowel_diacritic
# 14   Test_4_consonant_diacritic
# 15         Test_5_grapheme_root
# 16       Test_5_vowel_diacritic
# 17   Test_5_consonant_diacritic
# 18         Test_6_grapheme_root
# 19       Test_6_vowel_diacritic
# 20   Test_6_consonant_diacritic
# 21         Test_7_grapheme_root
# 22       Test_7_vowel_diacritic
# 23   Test_7_consonant_diacritic
# 24         Test_8_grapheme_root
# 25       Test_8_vowel_diacritic
# 26   Test_8_consonant_diacritic
# 27         Test_9_grapheme_root
# 28       Test_9_vowel_diacritic
# 29   Test_9_consonant_diacritic
# 30        Test_10_grapheme_root
# 31      Test_10_vowel_diacritic
# 32  Test_10_consonant_diacritic
# 33        Test_11_grapheme_root
# 34      Test_11_vowel_diacritic
# 35  Test_11_consonant_diacritic
#
#                                                target
# 0   [[1.2392502e-10, 6.4746004e-12, 4.548804e-10, ...
# 1   [[0.08225459, 0.055209737, 0.041423045, 1.0385...
# 2   [[0.9780934, 4.1071505e-07, 0.00018285705, 4.9...
# 3   [[1.2392502e-10, 6.4746004e-12, 4.548804e-10, ...
# 4   [[0.08225459, 0.055209737, 0.041423045, 1.0385...
# 5   [[0.9780934, 4.1071505e-07, 0.00018285705, 4.9...
# 6   [[1.2392502e-10, 6.4746004e-12, 4.548804e-10, ...
# 7   [[0.08225459, 0.055209737, 0.041423045, 1.0385...
# 8   [[0.9780934, 4.1071505e-07, 0.00018285705, 4.9...
# 9   [[1.5467683e-09, 3.6715428e-10, 6.3686745e-10,...
# 10  [[0.72644913, 0.0053312117, 0.1054116, 0.00080...
# 11  [[0.99978536, 1.7979725e-07, 0.00010392474, 6....
# 12  [[1.5467683e-09, 3.6715428e-10, 6.3686745e-10,...
# 13  [[0.72644913, 0.0053312117, 0.1054116, 0.00080...
# 14  [[0.99978536, 1.7979725e-07, 0.00010392474, 6....
# 15  [[1.5467683e-09, 3.6715428e-10, 6.3686745e-10,...
# 16  [[0.72644913, 0.0053312117, 0.1054116, 0.00080...
# 17  [[0.99978536, 1.7979725e-07, 0.00010392474, 6....
# 18  [[4.939918e-11, 2.6159042e-12, 1.6948474e-12, ...
# 19  [[0.106068425, 0.120595224, 0.004280043, 0.000...
# 20  [[0.99826366, 5.6528084e-08, 7.434308e-05, 2.7...
# 21  [[4.939918e-11, 2.6159042e-12, 1.6948474e-12, ...
# 22  [[0.106068425, 0.120595224, 0.004280043, 0.000...
# 23  [[0.99826366, 5.6528084e-08, 7.434308e-05, 2.7...
# 24  [[4.939918e-11, 2.6159042e-12, 1.6948474e-12, ...
# 25  [[0.106068425, 0.120595224, 0.004280043, 0.000...
# 26  [[0.99826366, 5.6528084e-08, 7.434308e-05, 2.7...
# 27  [[2.907742e-07, 9.683923e-08, 2.201181e-08, 7....
# 28  [[0.14623648, 0.021180792, 0.5491407, 0.131038...
# 29  [[0.9932655, 1.6316619e-05, 0.0023375878, 7.56...
# 30  [[2.907742e-07, 9.683923e-08, 2.201181e-08, 7....
# 31  [[0.14623648, 0.021180792, 0.5491407, 0.131038...
# 32  [[0.9932655, 1.6316619e-05, 0.0023375878, 7.56...
# 33  [[2.907742e-07, 9.683923e-08, 2.201181e-08, 7....
# 34  [[0.14623648, 0.021180792, 0.5491407, 0.131038...
# 35  [[0.9932655, 1.6316619e-05, 0.0023375878, 7.56...
